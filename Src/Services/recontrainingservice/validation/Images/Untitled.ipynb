# %%
import numpy as np
from skimage import measure
import scipy.misc
import cv2
image = scipy.misc.imread('6.png', mode='F').astype('float32')
# Out:
# /home/quest/anaconda3/envs/python-hackbluebytes/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """

# %%
import matplotlib.pyplot as plt

# %%
npad = ((56, 56), (0, 0), (0, 0))
image.shape
image
# Out:
# array([[166.858, 170.858, 169.744, ..., 199.588, 214.702, 215.93 ],
#        [166.858, 157.858, 163.858, ..., 201.229, 215.713, 208.186],
#        [175.744, 169.858, 164.858, ..., 202.3  , 213.3  , 205.072],
#        ...,
#        [164.65 , 169.361, 171.762, ...,  55.039,  65.082,  66.68 ],
#        [169.906, 150.432, 177.834, ...,  70.495,  73.338,  82.295],
#        [185.102, 184.575, 185.988, ...,  76.979,  82.936,  83.893]],
#       dtype=float32)

# %%
image = np.resize(image[144, 256, 1], [144, 256, 3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-49c5faa20a14> in <module>()
# ----> 1 image = np.resize(image[144, 256, 1], [144, 256, 3])
#
# IndexError: too many indices for array

# %%
plt.imshow(image)

# %%
img = cv2.imread('vhf.90.png')

# %%
plt.imshow(img)

# %%
blurred_img = cv2.GaussianBlur(img,(5,5),10)
plt.imshow(blurred_img)

# %%
blurred_img = cv2.GaussianBlur(img,(5,5),5)
plt.imshow(blurred_img)

# %%
blurred_img = cv2.GaussianBlur(img,(3,3),10)
plt.imshow(blurred_img)

# %%
blurred_img = cv2.GaussianBlur(img,(3,3),5)
plt.imshow(blurred_img)

# %%
blurred_img = cv2.GaussianBlur(img,(3,3),1)
plt.imshow(blurred_img)

# %%
blurred_img = cv2.GaussianBlur(img,(3,3),100)
plt.imshow(blurred_img)

# %%
blur = cv2.bilateralFilter(blurred_img,9,75,75)
plt.imshow(blur)

# %%
blurred_img = cv2.GaussianBlur(img,(3,3),0.9)
plt.imshow(blurred_img)

# %%
cv2.imwrite('vishnu.png', blurred_img)
# Out:
# True

# %%
from skimage import measure
ground = cv2.imread('/home/quest/DataSets/groundtruth/vhf18.png')
output = cv2.imread('output.png')

# %%
def psnr(img1, img2):
    mse = np.mean( (img1 - img2) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

# %%
print(psnr(ground,output))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-418a7a0714ec> in <module>()
# ----> 1 print(psnr(ground,output))
#
# <ipython-input-50-3003f48f58b6> in psnr(img1, img2)
#       1 def psnr(img1, img2):
# ----> 2     mse = np.mean( (img1 - img2) ** 2 )
#       3     if mse == 0:
#       4         return 100
#       5     PIXEL_MAX = 255.0
#
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'

# %%
import scipy

# %%
image = scipy.misc.imread(ground, mode='RGB').astype('float32')
# Out:
# /home/quest/anaconda3/envs/python-hackbluebytes/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/python-hackbluebytes/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2612     try:
# -> 2613         fp.seek(0)
#    2614     except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'NoneType' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-f441ae0d4eec> in <module>()
# ...
